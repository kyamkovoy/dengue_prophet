# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pickle
import os
import warnings
from matplotlib import pyplot as plt
from matplotlib import axes
warnings.simplefilter(action='ignore')
# %matplotlib inline

provinces = [10, 41, 50, 70, 90]
province_names = {10: 'Bangkok', 41: 'Udon Thani', 50: 'Ratchaburi', 70: 'Chiang Mai', 90: 'Songkla'}
province_names_list = ['Bangkok', 'Udon Thani', 'Ratchaburi', 'Chiang Mai', 'Songkla']

which_time0 = 'jan'
which_model = 'default_prophet'

folder = '../../output/' + which_time0 + '_time0/' + which_model

# %%
sns.set()
plt.style.use('seaborn-paper')

# %% [markdown]
# #### Define some functions to make everything easier:

# %%
# loads the error dataframe
def load_error_df(folder):
    # load the data
    file_path = folder + '/monthly_errors.csv'
    error_df = pd.read_csv(file_path)
    error_df['province'] = error_df['province'].astype(int)
    error_df['year'] = error_df['year'].astype(int)
    error_df['peak_month_error'] = error_df['peak_month_error'].astype(int)
    error_df = error_df.loc[error_df['year'] != 2007]
    
    return error_df

# %%
# makes a graph for specified province
def make_a_graph(folder, province):
    error_df = load_error_df(folder)
    prov_df = error_df.loc[error_df['province'] == province]
    ax = sns.barplot(x='year', y='monthly_case_rmse', data=prov_df, palette="Blues_d", ci=0)
    ax.set(xlabel='Year', ylabel='RMSE for Monthly Case Counts')
    plt.title(province_names[province])
    plt.show()

# %% [markdown]
# #### Here are the graphs that we want to make:
# - For each province, make a graph comparing the errors for the jan/jul time zeros for each year
#    - make different markers jan and jul, have years on the x-axis, errors on the y-axis
#    - do this for every target? end up having four subplots that way
# - Same idea, but the different models have different markers, make the jan/jul graphs side by side?
# - For each province, make a graph of the average errors (so for all the years) for the three models
#
# - Should probably look at the monthly rmse and yearly errors seperately? that would take editing the cv_monthly script

# %%
# just load all of the error dfs for quick access

hist_avg_folder = '../../output/hist_avg'
jan_default_prophet_folder = '../../output/jan_time0/default_prophet'
jan_cp_prophet_folder = '../../output/jan_time0/cp_prophet'
jul_default_prophet_folder = '../../output/jul_time0/default_prophet'
jul_cp_prophet_folder = '../../output/jul_time0/cp_prophet'

avg_error = load_error_df(hist_avg_folder)
jan_dp_error = load_error_df(jan_default_prophet_folder)
jan_cpp_error = load_error_df(jan_cp_prophet_folder)
jul_dp_error = load_error_df(jul_default_prophet_folder)
jul_cpp_error = load_error_df(jul_cp_prophet_folder)

# %%
avg_error.head()
# Out:
#    province  year  monthly_case_rmse  year_total_error  peak_error  \
# 1        10  2008         332.622827       2808.869534  626.516991
# 2        10  2009         174.602635       1683.308354   89.854456
# 3        10  2010         269.887844        937.489898  389.235904
# 4        10  2011         220.241434        142.994988  152.041951
# 5        10  2012         364.795071        349.841477  725.478439
#
#    peak_month_error
# 1                 4
# 2                 1
# 3                 0
# 4                 4
# 5                 1

# %% [markdown]
# ### Compare performance of the models numerically
#
# Load the errors for each model
# Compare each of the targets

# %%
# this function gets all of the AVERAGE errors for the specified target for all provinces

def avg_errors(province, which_error, which_time0, output = False):
    
    if which_time0 == 'jan':
        dp_error = jan_dp_error.loc[jan_dp_error['province'] == province]
        cpp_error = jan_cpp_error.loc[jan_cpp_error['province'] == province]
        prov_avg_error = avg_error.loc[avg_error['province'] == province]
        
        mpd_avg = dp_error[which_error].mean()
        mpcp_avg = cpp_error[which_error].mean()
        mavg_avg = prov_avg_error[which_error].mean()
    
    if which_time0 == 'jul':
        dp_error = jul_dp_error.loc[jul_dp_error['province'] == province]
        cpp_error = jul_cpp_error.loc[jul_cpp_error['province'] == province]
        prov_avg_error = avg_error.loc[avg_error['province'] == province]
        
        mpd_avg = dp_error[which_error].mean()
        mpcp_avg = cpp_error[which_error].mean()
        mavg_avg = prov_avg_error[which_error].mean()

    if output == True:
        print('default prophet errors for ' + which_error)
        print('   ' + str(mpd_avg))
        
        print()
        print('prophet w/ changepoint prior = 0.5 errors for ' + which_error)
        print('   ' + str(mpcp_avg))
        
        print()
        print('historical average errors for ' + which_error)
        print('   ' + str(mavg_avg))
    
    return [mpd_avg, mpcp_avg, mavg_avg]

# %%
# use this one for graphing ALL PROVINCES

def avg_errors_province_ys(which_error, which_time0, output = False):
    
    single_prov_errors = []
    for province in provinces:
        if which_time0 == 'jan':
            dp_error = jan_dp_error.loc[jan_dp_error['province'] == province]
            cpp_error = jan_cpp_error.loc[jan_cpp_error['province'] == province]
            prov_avg_error = avg_error.loc[avg_error['province'] == province]

            mpd_avg = dp_error[which_error].mean()
            mpcp_avg = cpp_error[which_error].mean()
            mavg_avg = prov_avg_error[which_error].mean()

        if which_time0 == 'jul':
            dp_error = jul_dp_error.loc[jul_dp_error['province'] == province]
            cpp_error = jul_cpp_error.loc[jul_cpp_error['province'] == province]
            prov_avg_error = avg_error.loc[avg_error['province'] == province]

            mpd_avg = dp_error[which_error].mean()
            mpcp_avg = cpp_error[which_error].mean()
            mavg_avg = prov_avg_error[which_error].mean()

        if output == True:
            print('default prophet errors for ' + which_error)
            print('   ' + str(mpd_avg))

            print()
            print('prophet w/ changepoint prior = 0.5 errors for ' + which_error)
            print('   ' + str(mpcp_avg))

            print()
            print('historical average errors for ' + which_error)
            print('   ' + str(mavg_avg))
    
        single_prov_errors.append([mpd_avg, mpcp_avg, mavg_avg])
    
    errors = pd.DataFrame(single_prov_errors, columns=['dp', 'cpp', 'hist_avg'])
    return errors

# %%
avg_errors_province_ys('monthly_case_rmse', 'jan')
# Out:
#            dp         cpp    hist_avg
# 0  473.718301  750.451415  425.586035
# 1   45.559822   63.616233   37.649414
# 2  160.081153  198.452987  127.401761
# 3   50.523706   66.850204   43.525565
# 4  195.746045  314.203022  165.426198

# %% [markdown]
# #### Graphs!
#
# - make a seperate graph for each of the targets
# - each graph has province on the x axis, error on the y axis, and markers for different models

# %%
# look at error in monthly counts first
# start w/ just january time zero
monthly_rmse = avg_errors_province_ys('monthly_case_rmse', 'jan')

xs = [1,2,3,4,5]
dp_ys = np.log(monthly_rmse['dp'])
cpp_ys = np.log(monthly_rmse['cpp'])
avg_ys = np.log(monthly_rmse['hist_avg'])

plt.figure(figsize=(3, 2))
plt.xticks(xs, province_names_list, rotation=30)

plt.title('RMSE in Monthly Case Counts: Jan')
plt.ylabel('log(average rmse)')
plt.xlim(.75, 5.25)

fig = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')
# plt.legend(['Prophet Model 1', 'Prophet Model 2', 'Historical Average Model'], frameon=True, shadow=True)

plt.show()

# %%
monthly_rmse = avg_errors_province_ys('year_total_error', 'jan')

xs = [1,2,3,4,5]
dp_ys = np.log(monthly_rmse['dp'])
cpp_ys = np.log(monthly_rmse['cpp'])
avg_ys = np.log(monthly_rmse['hist_avg'])

plt.figure(figsize=(3, 2))
plt.xticks(xs, province_names_list, rotation=30)

plt.title('Error in Yearly Total Case Counts: Jan')
plt.ylabel('log(average rmse)')
plt.xlim(.75, 5.25)
plt.xticks(xs, province_names_list)

fig = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')
# plt.legend(['Prophet Model 1', 'Prophet Model 2', 'Historical Average Model'])

plt.show()

# %%
monthly_rmse = avg_errors_province_ys('peak_error', 'jan')

xs = [1,2,3,4,5]
dp_ys = np.log(monthly_rmse['dp'])
cpp_ys = np.log(monthly_rmse['cpp'])
avg_ys = np.log(monthly_rmse['hist_avg'])

plt.figure(figsize=(3, 2))
plt.xticks(xs, province_names_list, rotation=30)

plt.title('Error in Peak Month Count: Jan')
plt.ylabel('log(average rmse)')
plt.xlim(.75, 5.25)
plt.xticks(xs, province_names_list)

fig = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')
# plt.legend(['Prophet Model 1', 'Prophet Model 2', 'Historical Average Model'])

plt.show()

# %%
monthly_rmse = avg_errors_province_ys('peak_month_error', 'jan')

xs = [1,2,3,4,5]
dp_ys = np.log(monthly_rmse['dp'])
cpp_ys = np.log(monthly_rmse['cpp'])
avg_ys = np.log(monthly_rmse['hist_avg'])

plt.figure(figsize=(3, 1.9))
plt.xticks(xs, province_names_list, rotation=30)

plt.title('Error in Peak Month: Jan')
plt.ylabel('log(average rmse)')
plt.xlim(.75, 5.25)
plt.xticks(xs, province_names_list)

fig = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')
# plt.legend(['Prophet Model 1', 'Prophet Model 2', 'Historical Average Model'])

plt.show()

# %%
# now repeat for july time zero
# monthly rmse
error = avg_errors_province_ys('monthly_case_rmse', 'jul')

xs = [1,2,3,4,5]
dp_ys = np.log(error['dp'])
cpp_ys = np.log(error['cpp'])
avg_ys = np.log(error['hist_avg'])

plt.figure(figsize=(3, 2))
plt.xticks(xs, province_names_list, rotation=30)

plt.title('RMSE in Monthly Case Counts: Jul')
plt.ylabel('log(average rmse)')
plt.xlim(.75, 5.25)
plt.xticks(xs, province_names_list)

fig1 = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')
# plt.legend(['Prophet Model 1', 'Prophet Model 2', 'Historical Average Model'])
plt.show()


# year total
error = avg_errors_province_ys('year_total_error', 'jul')

xs = [1,2,3,4,5]
dp_ys = np.log(error['dp'])
cpp_ys = np.log(error['cpp'])
avg_ys = np.log(error['hist_avg'])

plt.figure(figsize=(3, 2))
plt.xticks(xs, province_names_list, rotation=30)

plt.title('Error in Yearly Total Case Counts: Jul')
plt.ylabel('log(average rmse)')
plt.xlim(.75, 5.25)
plt.xticks(xs, province_names_list)

fig2 = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')
# plt.legend(['Prophet Model 1', 'Prophet Model 2', 'Historical Average Model'])
plt.show()


# peak count error
error = avg_errors_province_ys('peak_error', 'jul')

xs = [1,2,3,4,5]
dp_ys = np.log(error['dp'])
cpp_ys = np.log(error['cpp'])
avg_ys = np.log(error['hist_avg'])

plt.figure(figsize=(3, 2))
plt.xticks(xs, province_names_list, rotation=30)

plt.title('Error in Peak Month Count: Jul')
plt.ylabel('log(average rmse)')
plt.xlim(.75, 5.25)
plt.xticks(xs, province_names_list)

fig3 = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')
# plt.legend(['Prophet Model 1', 'Prophet Model 2', 'Historical Average Model'])
plt.show()


# peak month error
error = avg_errors_province_ys('peak_month_error', 'jul')

xs = [1,2,3,4,5]
dp_ys = np.log(error['dp'])
cpp_ys = np.log(error['cpp'])
avg_ys = np.log(error['hist_avg'])

plt.figure(figsize=(3, 1.9))
plt.xticks(xs, province_names_list, rotation=30)

plt.title('Error in Peak Month: Jul')
plt.ylabel('log(average rmse)')
plt.xlim(.75, 5.25)
plt.xticks(xs, province_names_list)

fig4 = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')
# plt.legend(['Prophet Model 1', 'Prophet Model 2', 'Historical Average Model'])

plt.show()

# %%
plt.subplot(4,2,1)
monthly_rmse = avg_errors_province_ys('monthly_case_rmse', 'jan')

xs = [1,2,3,4,5]
dp_ys = np.log(monthly_rmse['dp'])
cpp_ys = np.log(monthly_rmse['cpp'])
avg_ys = np.log(monthly_rmse['hist_avg'])
plt.title('RMSE in Monthly Case Counts: Jan')
# plt.ylabel('log(average rmse)')
plt.xlim(.75, 5.25)
plt.xticks([])
plt.yticks([])
fig = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')

plt.subplot(4,2,3)
monthly_rmse = avg_errors_province_ys('year_total_error', 'jan')
xs = [1,2,3,4,5]
dp_ys = np.log(monthly_rmse['dp'])
cpp_ys = np.log(monthly_rmse['cpp'])
avg_ys = np.log(monthly_rmse['hist_avg'])
plt.title('Error in Yearly Total Case Counts: Jan')
# plt.ylabel('log(error)')
plt.xlim(.75, 5.25)
plt.xticks([])
plt.yticks([])
fig = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')

plt.subplot(4,2,5)
monthly_rmse = avg_errors_province_ys('peak_error', 'jan')
xs = [1,2,3,4,5]
dp_ys = np.log(monthly_rmse['dp'])
cpp_ys = np.log(monthly_rmse['cpp'])
avg_ys = np.log(monthly_rmse['hist_avg'])
plt.title('Error in Peak Month Count: Jan')
# plt.ylabel('log(average rmse)')
plt.xlim(.75, 5.25)
plt.xticks([])
plt.yticks([])
fig = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')

plt.subplot(4,2,7)
monthly_rmse = avg_errors_province_ys('peak_month_error', 'jan')
xs = [1,2,3,4,5]
dp_ys = np.log(monthly_rmse['dp'])
cpp_ys = np.log(monthly_rmse['cpp'])
avg_ys = np.log(monthly_rmse['hist_avg'])
plt.title('Error in Peak Month: Jan')
# plt.ylabel('log(average rmse)')
plt.xlim(.75, 5.25)
plt.xticks(xs, province_names_list, rotation = 30)
plt.yticks([])
fig = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')


plt.subplot(4,2,2)
error = avg_errors_province_ys('monthly_case_rmse', 'jul')
xs = [1,2,3,4,5]
dp_ys = np.log(error['dp'])
cpp_ys = np.log(error['cpp'])
avg_ys = np.log(error['hist_avg'])
plt.title('RMSE in Monthly Case Counts: Jul')
# plt.ylabel('log(average rmse)')
plt.xlim(.75, 5.25)
plt.xticks([])
plt.yticks([])
fig1 = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')

plt.subplot(4,2,4)
error = avg_errors_province_ys('year_total_error', 'jul')
xs = [1,2,3,4,5]
dp_ys = np.log(error['dp'])
cpp_ys = np.log(error['cpp'])
avg_ys = np.log(error['hist_avg'])
plt.title('Error in Yearly Total Case Counts: Jul')
# plt.ylabel('log(average rmse)')
plt.xlim(.75, 5.25)
plt.xticks([])
plt.yticks([])
fig2 = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')

plt.subplot(4,2,6)
error = avg_errors_province_ys('peak_error', 'jul')
xs = [1,2,3,4,5]
dp_ys = np.log(error['dp'])
cpp_ys = np.log(error['cpp'])
avg_ys = np.log(error['hist_avg'])
plt.title('Error in Peak Month Count: Jul')
# plt.ylabel('log(average rmse)')
plt.xlim(.75, 5.25)
plt.xticks([])
plt.yticks([])
fig3 = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')

plt.subplot(4,2,8)
error = avg_errors_province_ys('peak_month_error', 'jul')
xs = [1,2,3,4,5]
dp_ys = np.log(error['dp'])
cpp_ys = np.log(error['cpp'])
avg_ys = np.log(error['hist_avg'])
plt.title('Error in Peak Month: Jul')
# plt.ylabel('log(average rmse)')
plt.xlim(.75, 5.25)
plt.xticks([])
plt.yticks([])
fig4 = plt.plot(xs, dp_ys, 'o', xs, cpp_ys, '^', xs, avg_ys, 'd')

plt.xticks(xs, province_names_list, rotation = 30)
plt.legend(['Prophet Model 1', 'Prophet Model 2', 'Historical Average Model'], frameon=True, shadow=True)
plt.tight_layout
plt.show()

# %%
def avg_error_graphs()

x = ['mpd', 'bpd', 'mpcp', 'bpcp', 'mavg', 'bavg']

plt.subplot(2, 2, 1)
ax = sns.barplot(x=x, y=monthly_case_rmse, palette="Paired", ci=0)
ax.set(xlabel='Model', ylabel='Error (cases)')
plt.title('Average RMSE in Monthly Case Counts')


plt.subplot(2,2,2)
ax = sns.barplot(x=x, y=year_total_error, palette="Paired", ci=0)
ax.set(xlabel='Model', ylabel='Error (cases)')
plt.title('Average Error in Yearly Total Case Count')

plt.subplot(2,2,3)
ax = sns.barplot(x=x, y=peak_error, palette="Paired", ci=0)
ax.set(xlabel='Model', ylabel='Error (cases)')
plt.title('Average Error in Peak Case')

plt.subplot(2,2,4)
ax = sns.barplot(x=x, y=peak_month_error, palette="Paired", ci=0)
ax.set(xlabel='Model', ylabel='Error (months)')
plt.title('Average Error in Peak Month')

plt.tight_layout()
plt.show()
