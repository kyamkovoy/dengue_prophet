# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pickle
import os
import warnings
from matplotlib import pyplot as plt
from matplotlib import axes
warnings.simplefilter(action='ignore')
# %matplotlib inline

provinces = [10, 41, 50, 70, 90]
province_names = {10: 'Bangkok', 41: 'Udon Thani', 50: 'Ratchaburi', 70: 'Chiang Mai', 90: 'Songkla'}

which_time0 = 'jan'
which_model = 'default_prophet'

folder = '../../output/' + which_time0 + '_time0/' + which_model

# %% [markdown]
# #### Define some functions to make everything easier:

# %%
# loads the error dataframe
def load_error_df(folder):
    # load the data
    file_path = folder + '/monthly_errors.csv'
    error_df = pd.read_csv(file_path)
    error_df['province'] = error_df['province'].astype(int)
    error_df['year'] = error_df['year'].astype(int)
    error_df['peak_month_error'] = error_df['peak_month_error'].astype(int)
    error_df = error_df.loc[error_df['year'] != 2007]
    
    return error_df

# %%
# makes a graph for specified province
def make_a_graph(folder, province):
    error_df = load_error_df(folder)
    prov_df = error_df.loc[error_df['province'] == province]
    ax = sns.barplot(x='year', y='monthly_case_rmse', data=prov_df, palette="Blues_d", ci=0)
    ax.set(xlabel='Year', ylabel='RMSE for Monthly Case Counts')
    plt.title(province_names[province])
    plt.show()

# %% [markdown]
# #### Here are the graphs that we want to make:
# - For each province, make a graph comparing the errors for the jan/jul time zeros for each year
#    - make different markers jan and jul, have years on the x-axis, errors on the y-axis
#    - do this for every target? end up having four subplots that way
# - Same idea, but the different models have different markers, make the jan/jul graphs side by side?
# - For each province, make a graph of the average errors (so for all the years) for the three models
#
# - Should probably look at the monthly rmse and yearly errors seperately? that would take editing the cv_monthly script

# %%
# just load all of the error dfs for quick access

hist_avg_folder = '../../output/hist_avg'
jan_default_prophet_folder = '../../output/jan_time0/default_prophet'
jan_cp_prophet_folder = '../../output/jan_time0/cp_prophet'
jul_default_prophet_folder = '../../output/jul_time0/default_prophet'
jul_cp_prophet_folder = '../../output/jul_time0/cp_prophet'

avg_error = load_error_df(hist_avg_folder)
jan_dp_error = load_error_df(jan_default_prophet_folder)
jan_cpp_error = load_error_df(jan_cp_prophet_folder)
jul_dp_error = load_error_df(jul_default_prophet_folder)
jul_cpp_error = load_error_df(jul_cp_prophet_folder)

# %%
make_a_graph(hist_avg_folder, 10)

# %% [markdown]
# ### Compare performance of the models numerically
#
# Load the errors for each model
# Compare each of the targets

# %%
# one month out
m_prophet_default = load_error_df('../../output/default_prophet/all_prov_monthly/all_prov_monthly_', 1)
m_prophet_cp = load_error_df('../../output/prophet_changepoint_0.5/all_prov_monthly/all_prov_monthly_', 1)
m_hist_avg = load_error_df('../../output/hist_avg/all_prov_monthly/all_prov_monthly_', 1)

b_prophet_default = b_load_error_df('../../output/default_prophet/all_prov_biweekly/all_prov_biweekly_', 1)
b_prophet_cp = b_load_error_df('../../output/prophet_changepoint_0.5/all_prov_biweekly/all_prov_biweekly_', 1)
b_hist_avg = b_load_error_df('../../output/hist_avg/all_prov_biweekly/all_prov_biweekly_', 1)

# %%
# this function gets all of the AVERAGE errors for the specified target for all provinces

def avg_errors(which_error, output = False):
    mpd_avg = m_prophet_default[which_error].mean()
    bpd_avg = b_prophet_default[which_error].mean()

    mpcp_avg = m_prophet_cp[which_error].mean()
    bpcp_avg = b_prophet_cp[which_error].mean()

    mavg_avg = m_hist_avg[which_error].mean()
    bavg_avg = b_hist_avg[which_error].mean()
    
    if output == True:
        print('default prophet errors for ' + which_error + ', one year out:')
        print('monthly: ' + str(mpd_avg))
        print('biweekly: ' + str(bpd_avg))
        
        print()
        print('prophet w/ changepoint prior = 0.5 errors for ' + which_error + ', one year out:')
        print('monthly: ' + str(mpcp_avg))
        print('biweekly: ' + str(bpcp_avg))
        
        print()
        print('historical average errors for ' + which_error + ', one year out:')
        print('monthly: ' + str(mavg_avg))
        print('biweekly: ' + str(bavg_avg))
    
    return [mpd_avg, bpd_avg, mpcp_avg, bpcp_avg, mavg_avg, bavg_avg]

# %%
monthly_case_rmse = avg_errors('monthly_case_rmse')
year_total_error = avg_errors('year_total_error')
peak_error = avg_errors('peak_error')
peak_month_error = avg_errors('peak_month_error')

# %%
sns.set()
plt.style.use('seaborn-paper')

# %%
x = ['mpd', 'bpd', 'mpcp', 'bpcp', 'mavg', 'bavg']

plt.subplot(2, 2, 1)
ax = sns.barplot(x=x, y=monthly_case_rmse, palette="Paired", ci=0)
ax.set(xlabel='Model', ylabel='Error (cases)')
plt.title('Average RMSE in Monthly Case Counts')


plt.subplot(2,2,2)
ax = sns.barplot(x=x, y=year_total_error, palette="Paired", ci=0)
ax.set(xlabel='Model', ylabel='Error (cases)')
plt.title('Average Error in Yearly Total Case Count')

plt.subplot(2,2,3)
ax = sns.barplot(x=x, y=peak_error, palette="Paired", ci=0)
ax.set(xlabel='Model', ylabel='Error (cases)')
plt.title('Average Error in Peak Case')

plt.subplot(2,2,4)
ax = sns.barplot(x=x, y=peak_month_error, palette="Paired", ci=0)
ax.set(xlabel='Model', ylabel='Error (months)')
plt.title('Average Error in Peak Month')

plt.tight_layout()
plt.show()

# %%
def avg_error_graphs()

x = ['mpd', 'bpd', 'mpcp', 'bpcp', 'mavg', 'bavg']

plt.subplot(2, 2, 1)
ax = sns.barplot(x=x, y=monthly_case_rmse, palette="Paired", ci=0)
ax.set(xlabel='Model', ylabel='Error (cases)')
plt.title('Average RMSE in Monthly Case Counts')


plt.subplot(2,2,2)
ax = sns.barplot(x=x, y=year_total_error, palette="Paired", ci=0)
ax.set(xlabel='Model', ylabel='Error (cases)')
plt.title('Average Error in Yearly Total Case Count')

plt.subplot(2,2,3)
ax = sns.barplot(x=x, y=peak_error, palette="Paired", ci=0)
ax.set(xlabel='Model', ylabel='Error (cases)')
plt.title('Average Error in Peak Case')

plt.subplot(2,2,4)
ax = sns.barplot(x=x, y=peak_month_error, palette="Paired", ci=0)
ax.set(xlabel='Model', ylabel='Error (months)')
plt.title('Average Error in Peak Month')

plt.tight_layout()
plt.show()
